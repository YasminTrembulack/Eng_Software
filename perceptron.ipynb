# %%
# Biblioteca necessária
import numpy as np

# %%
# Dados de entrada e saída esperada
entradas = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

# saidas = np.array([0, 0, 0, 1]) # AND
# saidas = np.array([0, 1, 1, 1]) # OR
saidas = np.array([0, 1, 1, 0])  # XOR

# %%
# Parâmetros
pesos = np.random.uniform(-1, 1, 2)  # pesos aleatórios
bias = np.random.uniform(-1, 1)      # bias aleatório
taxa_aprendizado = 0.1
epocas = 100

# %%
# Função degrau
def step(soma):
  return 1 if soma >= 0 else 0

# %%
# Treinamento
for epoca in range(epocas):
    erro_total = 0
    for i in range(len(entradas)):
        x = entradas[i]
        y = saidas[i]

        soma = np.dot(x, pesos) + bias
        y_pred = step(soma)
        erro = y - y_pred

        # Atualização dos pesos e bias
        pesos += taxa_aprendizado * erro * x
        bias += taxa_aprendizado * erro
        erro_total += abs(erro)

    print(f'Época {epoca+1} - Erro total: {erro_total}')
    if erro_total == 0:
        break
# Out:
# Época 1 - Erro total: 1
# Época 2 - Erro total: 2
# Época 3 - Erro total: 1
# Época 4 - Erro total: 2
# Época 5 - Erro total: 2
# Época 6 - Erro total: 1
# Época 7 - Erro total: 3
# Época 8 - Erro total: 1
# Época 9 - Erro total: 3
# Época 10 - Erro total: 1
# Época 11 - Erro total: 3
# Época 12 - Erro total: 3
# Época 13 - Erro total: 4
# Época 14 - Erro total: 4
# Época 15 - Erro total: 4
# Época 16 - Erro total: 4
# Época 17 - Erro total: 4
# Época 18 - Erro total: 4
# Época 19 - Erro total: 4
# Época 20 - Erro total: 4
# Época 21 - Erro total: 4
# Época 22 - Erro total: 4
# Época 23 - Erro total: 4
# Época 24 - Erro total: 4
# Época 25 - Erro total: 4
# Época 26 - Erro total: 4
# Época 27 - Erro total: 4
# Época 28 - Erro total: 4
# Época 29 - Erro total: 4
# Época 30 - Erro total: 4
# Época 31 - Erro total: 4
# Época 32 - Erro total: 4
# Época 33 - Erro total: 4
# Época 34 - Erro total: 4
# Época 35 - Erro total: 4
# Época 36 - Erro total: 4
# Época 37 - Erro total: 4
# Época 38 - Erro total: 4
# Época 39 - Erro total: 4
# Época 40 - Erro total: 4
# Época 41 - Erro total: 4
# Época 42 - Erro total: 4
# Época 43 - Erro total: 4
# Época 44 - Erro total: 4
# Época 45 - Erro total: 4
# Época 46 - Erro total: 4
# Época 47 - Erro total: 4
# Época 48 - Erro total: 4
# Época 49 - Erro total: 4
# Época 50 - Erro total: 4
# Época 51 - Erro total: 4
# Época 52 - Erro total: 4
# Época 53 - Erro total: 4
# Época 54 - Erro total: 4
# Época 55 - Erro total: 4
# Época 56 - Erro total: 4
# Época 57 - Erro total: 4
# Época 58 - Erro total: 4
# Época 59 - Erro total: 4
# Época 60 - Erro total: 4
# Época 61 - Erro total: 4
# Época 62 - Erro total: 4
# Época 63 - Erro total: 4
# Época 64 - Erro total: 4
# Época 65 - Erro total: 4
# Época 66 - Erro total: 4
# Época 67 - Erro total: 4
# Época 68 - Erro total: 4
# Época 69 - Erro total: 4
# Época 70 - Erro total: 4
# Época 71 - Erro total: 4
# Época 72 - Erro total: 4
# Época 73 - Erro total: 4
# Época 74 - Erro total: 4
# Época 75 - Erro total: 4
# Época 76 - Erro total: 4
# Época 77 - Erro total: 4
# Época 78 - Erro total: 4
# Época 79 - Erro total: 4
# Época 80 - Erro total: 4
# Época 81 - Erro total: 4
# Época 82 - Erro total: 4
# Época 83 - Erro total: 4
# Época 84 - Erro total: 4
# Época 85 - Erro total: 4
# Época 86 - Erro total: 4
# Época 87 - Erro total: 4
# Época 88 - Erro total: 4
# Época 89 - Erro total: 4
# Época 90 - Erro total: 4
# Época 91 - Erro total: 4
# Época 92 - Erro total: 4
# Época 93 - Erro total: 4
# Época 94 - Erro total: 4
# Época 95 - Erro total: 4
# Época 96 - Erro total: 4
# Época 97 - Erro total: 4
# Época 98 - Erro total: 4
# Época 99 - Erro total: 4
# Época 100 - Erro total: 4

# %%
# Impressão em formato de tabela
print("\nPesos finais:", pesos)
print("Bias final:", bias)
print("\nResultado final - Tabela de verdade aprendida:")
print("x1 | x2 | Soma   | y_real | y_previsto")
print(50*"-")
for i in range(len(entradas)):
    x = entradas[i]
    y = saidas[i]
    soma = np.dot(x, pesos) + bias
    y_pred = step(soma)
    print(f" {x[0]}  | {x[1]}  | {soma:6.2f} |   {y}    |     {y_pred}")
# Out:
# Pesos finais: [-0.17664182 -0.05227489]
# Bias final: 0.08415694498879331
#
# Resultado final - Tabela de verdade aprendida:
# x1 | x2 | Soma   | y_real | y_previsto
# --------------------------------------------------
#  0  | 0  |   0.08 |   0    |     1
#  0  | 1  |   0.03 |   1    |     1
#  1  | 0  |  -0.09 |   1    |     0
#  1  | 1  |  -0.14 |   0    |     0
